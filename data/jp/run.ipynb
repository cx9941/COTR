# %%
import pandas as pd
import json
import pandas as pd
import os
ans = []
for i in os.listdir('raw_data'):
    if i.endswith('json'):
        temp = json.load(open(f'raw_data/{i}', 'r'))
        cols = ['Job_Title', 'Job_description']
        temp = pd.DataFrame(temp)[cols]
        temp.columns = ['job_title', 'job_description']
    if i.endswith('csv'):
        cols = ['title', 'description']
        temp = pd.read_csv(f'raw_data/{i}')[cols]
        temp.columns = ['job_title', 'job_description']
    ans.append(temp)
df = pd.concat(ans)
df.to_csv('job_description.csv', index=None, sep='\t')
df
# Out:
#                                           job_title  \
# 0                              Webデザイナー(スポットでの制作委託)
# 1                             WEBデザイナー・HTMLコーダー[兼務]
# 2                                   webディレクター・デザイナー
# 3                             WEBデザイナー・プログラマー・エンジニア
# 4                                          WEBデザイナー
# ..                                              ...
# 370           トランスフォーメーション領域におけるデータサイエンティスト(シニアクラス)
# 371                        SDGアドテクseniorプロダクトマネージャー
# 372             IT・エンジニア(人材紹介/プロダクトエンジニア/経験者のみ/正社員)
# 373                                     PM・PL,SE・PG
# 374  プロダクト開発プロジェクトマネージャー(ユーザーファースト起点) [プロダクト本部本部付け]
#
#                                        job_description
# 0    \n \n  Ｗｅｂデザイナー（スポットでの制作委託）を募集します。\n \n \n  ２０...
# 1    主な仕事内容\n「店舗集客」に特化したWEBサイト・スマホサイトのデザイナー、コーダー業務を...
# 2    \n \n  スキルアップと安定収入を弊社で\n \n \n  弊社の持つ豊富な案件によりス...
# 3    ～絶対条件～\n社が向かう未来に共感できる方で、生涯サポートしてくれる人材を求めます。\n\...
# 4    \n 勤務内容 \n \n  ＷＥＢデザイナー\n \n 勤務地 \n \n  国頭郡恩納村...
# ..                                                 ...
# 370
# 371
# 372  [リモートワークOK!/ブランクがある方でも入社まで手厚いフォローあり!] 【プロダクト・マ...
# 373
# 374
#
# [3986 rows x 2 columns]
