# %%
import pandas as pd
df = pd.read_csv('raw_data/linkedln_total.csv', sep='\t')
df
# Out:
#           l0                                  l1  \
# 0       root                         Real Estate
# 1       root       Wellness and Fitness Services
# 2       root                         Restaurants
# 3       root                        Law Practice
# 4       root       Wellness and Fitness Services
# ...      ...                                 ...
# 108550  root                        Law Practice
# 108551  root                Software Development
# 108552  root   Education Administration Programs
# 108553  root  Industrial Machinery Manufacturing
# 108554  root       IT Services and IT Consulting
#
#                                                      text
# 0       Job descriptionA leading real estate firm in N...
# 1       At Aspen Therapy and Wellness , we are committ...
# 2       The National Exemplar is accepting application...
# 3       Senior Associate Attorney - Elder Law / Trusts...
# 4       Looking for HVAC service tech with experience ...
# ...

# %%
df[['text']].to_csv('all_data.csv', index=None, sep='\t')
