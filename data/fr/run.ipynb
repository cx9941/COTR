# %%
import pandas as pd
df = pd.read_csv('raw_data/offers.tsv', sep='\t')
df
# Out:
#       id Compagnie                                     Titre du poste  \
# 0      0  68e2bc6d          Technicien en administration des contrats
# 1      1  68e2bc6d             Préposé de service aux administrateurs
# 2      2  68e2bc6d  Préposé de service aux administrateurs – Bilingue
# 3      3  68e2bc6d          Technicien en administration des contrats
# 4      4  68e2bc6d                     Agent de soutien administratif
# ..   ...       ...                                                ...
# 886  886  7b28d5cd                      Agent ou Agente Souscripteur
# 887  887  7b28d5cd  Agent ou Agente service à la clientèle - Relat...
# 888  888  7b28d5cd  Agent ou Agente - Service à la clientèle - Rel...
# 889  889  7b28d5cd  Agent ou Agente - Service à la clientèle - Pro...
# 890  890  7b28d5cd  Conseiller ou Conseillère - Services à la clie...
#
#     Date limite de réception candidatures  \
# 0                              04-02-2010
# ...

# %%
print(df['Description Interne'][0])
# Out:
# Analyser les méthodes de travail des preneurs et développer des outils de travail afin de faciliter le traitement interne.
# Communiquer avec les administrateurs des régimes d’assurance afin de les sensibiliser et de les guider en matière de gestion administrative d’assurance.
# Effectuer les opérations techniques ou complexes reliées à la mise en place des nouveaux groupes, aux renouvellements de groupes, aux mouvements des adhérents, à l’adhésion, à la facturation et à l’encaissement.
# S’assurer que les besoins en matière de gestion administrative des administrateurs des régimes d’assurance soient bien définis, en collaboration avec la direction de l’actuariat et les directions des ventes.
# Maintenir à jour l’intranet et l’extranet de la direction.
# Fournir un support technique aux chefs d’équipe.
# Fournir un support technique aux différentes équipes impliquées dans la gestion des groupes.
# Maîtriser les systèmes de paie des clients.
# Rédiger les procédures de travail.
# ...
