# %%
import pandas as pd
import os

for dataset_name in ['eu', 'en', 'jp']:
    df = pd.read_excel(f'../step3-bert_recall/CuBERT/results/{dataset_name}/2e-05_32_0.8/{dataset_name}.xlsx')
    df.to_csv(f'data/{dataset_name}.csv', index=None, sep='\t')
df
# Out:
#                                    job_title  \
# 0          【プロダクトマネージャー】/インターネット/Webサービス・ASP
# 1                            データ入力・一般事務スタッフS
# 2                            Go/BaaSプロダクトの開発
# 3             【共創プロダクトマネージャー】マネーフォワードエックス_東京
# 4     デザイン業務(グラフィックデザイン、DTPデザイン、webデザイン)(石川)
# ...                                      ...
# 2963                                    品質保証
# 2964                                品質保証(機械)
# 2965                       取引先の品質保証体制監査と改善指導
# 2966         税理士事務所で会計入力事務からスタートする長期インターンシップ
# 2967                               産婦人科の医療事務
#
#                                         job_description  \
# 0     まちの回遊性向上を図れるデジタルスタンプラリーやデジタルクーポン機能、地域経済を活性化させる...
# 1     お客様（生命保険の加入者様）から提出された各種書類に不備（  記載もれ、書類の不足等）が無い...
# 2     プロダクトマネージャが提示するプロダクトのビジョンや要件を、主に技術的な観点からブレイクダウ...
# 3     様々な局面から参画いただくことがありますが、最大のスコープとしては、営業支援から始まり、企画...
# 4     ロゴやパッケージ、会社案内、社内報、広告デザイン、カタログ/リーフレットなどの企画からDTP...
# ...                                                 ...
# 2963                                             監査対応など
# 2964                                             データの分析
# 2965                                             お客様に安全
# 2966                                             決算業務補助
# 2967                                             診療報酬請求
#
#                                                    text  \
# 0     【プロダクトマネージャー】/インターネット/Webサービス・ASP-まちの回遊性向上を図れる...
# 1     データ入力・一般事務スタッフS-お客様（生命保険の加入者様）から提出された各種書類に不備（ ...
# 2     Go/BaaSプロダクトの開発-プロダクトマネージャが提示するプロダクトのビジョンや要件を、...
# 3     【共創プロダクトマネージャー】マネーフォワードエックス_東京-様々な局面から参画いただくこと...
# 4     デザイン業務(グラフィックデザイン、DTPデザイン、webデザイン)(石川)-ロゴやパッケー...
# ...                                                 ...
# 2963                                        品質保証-監査対応など
# 2964                                    品質保証(機械)-データの分析
# 2965                           取引先の品質保証体制監査と改善指導-お客様に安全
# 2966             税理士事務所で会計入力事務からスタートする長期インターンシップ-決算業務補助
# 2967                                   産婦人科の医療事務-診療報酬請求
#
#                                   task0  task0_sim  \
# 0        コンピュータ機器やハードウェアの使用方法を他の人に教えます。   0.997882
# 1     製品やサービスの設計や技術的特徴について技術担当者と話し合います。   0.997240
# 2           ライブラリまたはアーカイブ データベースを開発します。   0.996565
# 3            調査レポートまたはインシデントレポートを準備します。   0.997604
# 4           デジタル文書、データ、または画像をフォーマットします。   0.994667
# ...                                 ...        ...
# 2963     ヘルスケア関連のソフトウェア アプリケーションを設計します。   0.997286
# 2964              組織活動を評価するための手順を開発します。   0.996759
# 2965           データベースのパラメータまたは仕様を開発します。   0.997148
# 2966             マーケティング活動において他者と協力します。   0.997589
# 2967                           がん治療を施す。   0.999398
#
#                                            task1  task1_sim  \
# 0             コンピューターで生成されたグラフィックやアニメーションを作成します。   0.997732
# 1                 コンピュータ機器やハードウェアの使用方法を他の人に教えます。   0.997095
# 2                            マーケティング計画や戦略を策定します。   0.995970
# 3                       人事ポリシーまたは人事慣行の有効性を評価します。   0.996919
# 4                    予測データを分析してビジネス上の意思決定を改善します。   0.993577
# ...                                          ...        ...
# 2963  科学的または技術的な使用を目的としたソフトウェアまたはアプリケーションを開発します。   0.997264
# 2964                        医療用または歯科用補助機器を修理します。   0.996723
# 2965                                家畜管理方法を研究する。   0.997129
# 2966                         市民プロジェクトや公共政策を評価する。   0.993431
# 2967                          医療現場における事務業務を行います。   0.999359
#
#                                    task2  task2_sim  \
# 0      製品やサービスの設計や技術的特徴について技術担当者と話し合います。   0.997431
# 1     コンピューターで生成されたグラフィックやアニメーションを作成します。   0.997028
# 2                   ビジネス戦略または市場戦略を策定します。   0.995834
# 3      財務記録を検査して、ポリシーや規制に準拠していることを確認します。   0.996811
# 4                      エネルギー生産データを評価します。   0.993454
# ...                                  ...        ...
# 2963                     労働時間や活動を文書化します。   0.997161
# 2964           口、歯、歯茎、または関連する顔の構造を検査します。   0.996673
# 2965          スタッフのスケジュールや仕事の割り当てを準備します。   0.997013
# 2966                    社会問題に関する調査を実施する。   0.992744
# 2967                         治療や療法を処方する。   0.999345
#
#                                          task3  ...  \
# 0              プロセスや製品を改善する方法について他の人にアドバイスします。  ...
# 1     エンジニアリングや設計活動に関連する人間のパフォーマンスや健康要因を研究します。  ...
# 2                              財務情報の正確性を確認します。  ...
# 3                         ビジネス戦略または市場戦略を策定します。  ...
# 4             コンピュータのハードウェアに関する推奨事項を他の人に提供します。  ...
# ...                                        ...  ...
# 2963                      運用データまたは生産データを記録します。  ...
# 2964                                航空機のパイロット。  ...
# 2965                              生徒の成績を監視します。  ...
# 2966                                生活スキルを教える。  ...
# 2967                  患者または治療データをコンピュータに入力します。  ...
#
#                                     task95 task95_sim  \
# 0                       技術文書を確認して作業を計画します。   0.994780
# 1                          新しい技術や方法を評価します。   0.994086
# 2                           専門分野における研究テーマ。   0.982273
# 3               教育や職業上の問題についてクライアントに助言します。   0.977162
# 4          顧客のニーズに合わせて金融商品やサービスをカスタマイズします。   0.985827
# ...                                    ...        ...
# 2963  製品、手順、ポリシーについてクライアントとコミュニケーションをとります。   0.993883
# 2964                 材料、機器、その他のリソースを購入します。   0.974977
# 2965            患者を他の医療従事者または医療リソースに紹介します。   0.994933
# 2966              ニュースや娯楽の目的で他の人にインタビューする。   0.860344
# 2967               健康上の問題を検出するために患者を監視します。   0.997956
#
#                              task96 task96_sim  \
# 0     作業割り当てを実行するための情報または指示を受け取ります。   0.994772
# 1     高度なエンジニアリング設計やアプリケーションを研究します。   0.993983
# 2             クラスやコミュニティイベントを主導します。   0.982121
# 3                   法的な事件に関して決定を下す。   0.977079
# 4             地質学的または地理学的データを分析します。   0.985787
# ...                             ...        ...
# 2963        マネージャーと協議して運用上の決定を下します。   0.993864
# 2964     化学処理または水処理システムまたは装置を操作します。   0.973379
# 2965   医療活動または手術が基準を満たしていることを確認します。   0.994930
# 2966  グリーンテクノロジーへの投資に関連するリスクを分析します。   0.859663
# 2967            X 線やその他の医療画像を処理します。   0.997903
#
#                                      task97 task97_sim  \
# 0                           学校や生徒の活動を監督します。   0.994757
# 1                              健康管理の授業を教える。   0.993939
# 2            従業員、顧客、その他の人にインタビューして情報を収集します。   0.981486
# 3                      顧客情報またはサービス記録を維持します。   0.976912
# 4     電話や双方向無線を使用して、事故や緊急事態に関する情報を担当者に伝えます。   0.985559
# ...                                     ...        ...
# 2963  電話や双方向無線を使用して、事故や緊急事態に関する情報を担当者に伝えます。   0.993850
# 2964                           現在の傾向を監視します。   0.972784
# 2965                              直接的な犯罪捜査。   0.994921
# 2966                   商品やサービスに対する代金を徴収します。   0.859637
# 2967             製品やサービスの使用について顧客にアドバイスします。   0.997892
#
#                                   task98 task98_sim  \
# 0                            規則や規制を施行する。   0.994742
# 1               活動を実行するための書面による許可を取得します。   0.993933
# 2                           顧客に投資を推奨します。   0.981266
# 3                 法的問題を調査するための公聴会を開催します。   0.976909
# 4            緊急事態、問題、または危険について他の人に通知します。   0.985369
# ...                                  ...        ...
# 2963  コンピュータまたは情報セキュリティのポリシーまたは手順を開発します。   0.993840
# 2964               建設、設置、修理のレイアウトを計画します。   0.972570
# 2965                 代替医療手法を用いて患者を治療します。   0.994914
# 2966                  価格やその他の販売条件を交渉します。   0.859355
# 2967                       実験室での作業を監督する。   0.997883
#
#                              task99 task99_sim
# 0               運用上の問題や障害の原因を特定します。   0.994730
# 1     技術的または手続き上の問題について顧客にアドバイスします。   0.993907
# 2           販売やその他のビジネス取引の記録を保持します。   0.980898
# 3               ライセンスまたは許可申請を確認します。   0.976744
# 4                状況の詳細を適切な担当者に伝えます。   0.985245
# ...                             ...        ...
# 2963                   健康や衛生習慣を教える。   0.993704
# 2964             アートやデザインの素材を確認します。   0.972462
# 2965         患者の身体的または生理学的特性を測定します。   0.994913
# 2966                 コストや販売条件を見積もる。   0.856358
# 2967           医療活動に関する数値データを計算します。   0.997872
#
# [2968 rows x 203 columns]
