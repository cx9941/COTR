# %%
import pandas as pd
import os

dataset_name = 'en'
seed = 0
title_occupation = pd.read_parquet(f'../step4-title_occupation/results/{dataset_name}/seed{seed}.parquet')
job_task = pd.read_csv(f'../step2-task_map_occupation/outputs/{dataset_name}/title_task.csv', sep='\t')

occupation_task = pd.read_csv(f'../data/{dataset_name}/task_occupation.csv', sep='\t')
# occupation_task = occupation_task[~occupation_task['task'].isna()]
occupation_task = occupation_task.groupby('occupation').agg(list).reset_index()

title_occupation['occupation'] = title_occupation['occupation'].apply(lambda x: x.strip(' '))
occupation_task['occupation'] = occupation_task['occupation'].apply(lambda x: x.strip(' '))
occupation_task.columns = ['occupation', 'task_candidate']

job_task = pd.merge(job_task, title_occupation, on=['title'])
job_task = pd.merge(job_task, occupation_task, on=['occupation'])
if not os.path.exists(f'data/{dataset_name}'):
    os.makedirs(f'data/{dataset_name}')
job_task.to_parquet(f'data/{dataset_name}/task_candidate.parquet')
df = job_task[['description', 'task_candidate']]
df.columns = ['job description', 'task_candidate']
for seed in range(5):
    if not os.path.exists(f'data/{dataset_name}/seed{seed}/input0'):
        os.makedirs(f'data/{dataset_name}/seed{seed}/input0')
    df.to_parquet(f'data/{dataset_name}/seed{seed}/input0/task_candidate.parquet')
df
# Out:
#                                           job description  \
# 0       Managing brand strategy and messaging through ...
# 1       Manage Contacts & Vendors for Event Planning &...
# 2       Track Tasks & Communicate with Marketing team ...
# 3       Support the Planning & Transportation Manager ...
# 4       Job summary:The Economic Development & Plannin...
# ...                                                   ...
# 101855  Design Verification experience, specifically r...
# 101856  Organize and transport all necessary sales and...
# 101857  The Business Development Manager is a 'hunter'...
# 101858  Track and report on competitors within defined...
# 101859  Develop relationships with clients in defined ...
#
#                                            task_candidate
# 0       [Identify, develop, or evaluate marketing stra...
# 1       [Identify, develop, or evaluate marketing stra...
# 2       [Identify, develop, or evaluate marketing stra...
# 3       [Observe work of teaching staff to evaluate pe...
# 4       [Observe work of teaching staff to evaluate pe...
# ...                                                   ...
# 101855  [Troubleshoot new or existing product problems...
# 101856  [Advise clients on aspects of capitalization, ...
# 101857  [Direct and coordinate activities involving sa...
# 101858  [Direct and coordinate activities involving sa...
# 101859  [Direct and coordinate activities involving sa...
#
# [101860 rows x 2 columns]
