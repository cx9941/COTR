# %%
import pandas as pd
import os

dataset_name = 'en'
seed=0
result_dir = f'results/{dataset_name}/seed{seed}'
final_ans = []

job_task = pd.read_csv(f'../step2-task_map_occupation/outputs/{dataset_name}/job_task.csv', sep='\t')[['title', 'task']]
job_task.columns = ['title', 'job description']
final_task = pd.read_parquet(f'results/{dataset_name}/seed0/result0.parquet')[['job description', 'task']]
final_task = pd.merge(final_task, job_task, on=['job description'])
final_task
# Out:
#                                          job description  \
# 0      Support the Planning & Transportation Manager ...
# 1      Job summary:The Economic Development & Plannin...
# 2      Plan (choice of 3 plans) with up to 100% indiv...
# 3      Support within 180 Days Required\nChildren’s i...
# 4      Exceptional vocal and/or instrumental talent- ...
# ...                                                  ...
# 44503  Coordinate with the Production Planning, Data ...
# 44504  Position Type: Full-time, exempt\n\nCompensati...
# 44505  Design, build, test, implement, and maintain c...
# 44506  25%Generate work instructions, test methods, e...
# 44507  Organize and transport all necessary sales and...
#
#                                                     task  \
# 0      Plan and conduct teacher training programs and...
# 1      Observe work of teaching staff to evaluate per...
# 2      Perform, or contract others to perform, pre-bu...
# 3      Demonstrate respiratory care procedures to tra...
# 4             Plan or lead religious education programs.
# ...                                                  ...
# 44503  Secure third-party verification from sources, ...
# 44504  Examine patients or order, perform, and interp...
# 44505  Write supporting code for Web applications or ...
# 44506  Determine root causes of failures or recommend...
# 44507  Determine the prices at which securities shoul...
#
#                                           title
# 0      Economic Development and Planning Intern
# 1      Economic Development and Planning Intern
# 2                             Building Engineer
# 3                         Respiratory Therapist
# 4                                Worship Leader
# ...                                         ...
# 44503                       Cultivation Manager
# 44504                       Attending Physician
# 44505                    React Native Developer
# 44506         Research And Development Engineer
# 44507      Account Executive, Oregon/Washington
#
# [44508 rows x 3 columns]

# %%
occupation_candidate = pd.read_parquet(f'../step4-title_occupation/data/{dataset_name}/seed0/input0/occupation_candidate.parquet').drop_duplicates('title')
title_occupation = pd.read_parquet(f'../step4-title_occupation/results/{dataset_name}/seed0.parquet')
title_occupation = pd.merge(title_occupation, occupation_candidate[['title', 'occupation_sim']], on='title')
title_occupation
# Out:
#                                                    title  \
# 0                             Stuffer Operator 2nd Shift
# 1      Cage Repair Attendant Maintenance-1st Shift- N...
# 2                                Sales Account Associate
# 3                 Personnel Security (PERSEC) Specialist
# 4                                NP/PA - Plastic Surgery
# ...                                                  ...
# 70732  Transfer Center Liaison - Transfer Center - Fu...
# 70733                        Events Sales Representative
# 70734                 Senior Manager, Corporate Strategy
# 70735                          Program Manager: 24-00941
# 70736  Retail Customer Experience Associate, Castleto...
#
#                                               occupation  occupation_sim
# 0                                  Pile Driver Operators        0.792738
# 1      Helpers--Installation, Maintenance, and Repair...        0.715460
# 2                                    Retail Salespersons        0.853999
# 3                        Security Management Specialists        0.841249
# 4                             Family Medicine Physicians        0.758527
# ...                                                  ...             ...
# 70732  First-Line Supervisors of Entertainment and Re...        0.682910
# 70733                                     Sales Managers        0.854420
# 70734                    General and Operations Managers        0.810812
# 70735                     Project Management Specialists        0.738595
# 70736                                Retail Salespersons        0.781954
#
# [70737 rows x 3 columns]

# %%
final_task = pd.merge(final_task, title_occupation, on='title')[['title', 'job description', 'occupation', 'task', 'occupation_sim']]
final_task.columns = ['job title', 'job description', 'occupation', 'task', 'similarity']
final_task = final_task.sort_values('similarity', ascending=False)
final_task.to_csv(f'results/{dataset_name}/seed0.csv', sep='\t', index=None)
final_task.to_excel(f'results/{dataset_name}/seed0.xlsx', index=None)
final_task
# Out:
#                                                job title  \
# 43830                       Customer Support Specialists
# 8545                             Quality Control Analyst
# 8546                             Quality Control Analyst
# 6608                    Healthcare Facilities Technician
# 9042                         Business Continuity Analyst
# ...                                                  ...
# 13132  Field Director, Therapeutic Education Leadersh...
# 13133  Field Director, Therapeutic Education Leadersh...
# 13131  Field Director, Therapeutic Education Leadersh...
# 41262  AWS Cloud IT Project Manager (CLD-0226A) // 10...
# 9125                                           지역 영업 관리자
#
#                                          job description  \
# 43830  Support at NexHealth\n\nIt is an exciting time...
# 8545   Routine Environmental Monitoring and utilities...
# 8546   Coordinate calibration schedules of assets and...
# 6608   Maintain cleanliness and orderliness of immedi...
# 9042   Assist in the coordination with IT and network...
# ...                                                  ...
# 13132  This person will be an active leader on our le...
# 13133  going team development by providing field and ...
# 13131  in-class services to support the bleeding diso...
# 41262  Complete DescriptionWe are looking for an AWS ...
# 9125   The ideal candidate will prospect and close sa...
#
#                                               occupation  \
# 43830                   Customer Service Representatives
# 8545                            Quality Control Analysts
# 8546                            Quality Control Analysts
# 6608                                Pharmacy Technicians
# 9042                      Project Management Specialists
# ...                                                  ...
# 13132  Atmospheric, Earth, Marine, and Space Sciences...
# 13133  Atmospheric, Earth, Marine, and Space Sciences...
# 13131  Atmospheric, Earth, Marine, and Space Sciences...
# 41262  Biofuels/Biodiesel Technology and Product Deve...
# 9125   Biofuels/Biodiesel Technology and Product Deve...
#
#                                                     task  similarity
# 43830  Contact customers to respond to inquiries or t...    0.927690
# 8545   Write technical reports or documentation, such...    0.912580
# 8546   Ensure that lab cleanliness and safety standar...    0.912580
# 6608   Clean and help maintain equipment or work area...    0.907098
# 9042   Develop or update project plans including info...    0.905668
# ...                                                  ...         ...
# 13132  Perform administrative duties, such as serving...    0.535170
# 13133  Prepare and deliver lectures to undergraduate ...    0.535170
# 13131  Maintain regularly scheduled office hours to a...    0.535170
# 41262  Develop computational tools or approaches to i...    0.520759
# 9125   Propose new biofuels products, processes, tech...    0.369749
#
# [44508 rows x 5 columns]

# %%
topk = 100
final_task[:topk].to_excel(f'results/{dataset_name}/seed{seed}_top{topk}.xlsx', index=None)
final_task[:topk]
# Out:
#                                            job title  \
# 43830                   Customer Support Specialists
# 8545                         Quality Control Analyst
# 8546                         Quality Control Analyst
# 6608                Healthcare Facilities Technician
# 9042                     Business Continuity Analyst
# ...                                              ...
# 33860     Human Resources Information System Analyst
# 31497                     Revenue Operations Analyst
# 16783  Construction Materials Engineering Technician
# 15995                   Market Data Business Analyst
# 21647                          Sales Support Analyst
#
#                                          job description  \
# 43830  Support at NexHealth\n\nIt is an exciting time...
# 8545   Routine Environmental Monitoring and utilities...
# 8546   Coordinate calibration schedules of assets and...
# 6608   Maintain cleanliness and orderliness of immedi...
# 9042   Assist in the coordination with IT and network...
# ...                                                  ...
# 33860  You will drive change by assessing and anticip...
# 31497  Support functional leaders within the company ...
# 16783  Plan (ESOP)401K with Company MatchingPTO with ...
# 15995  With over 238 years of rich history and indust...
# 21647  Support Analyst will provide support and will ...
#
#                              occupation  \
# 43830  Customer Service Representatives
# 8545           Quality Control Analysts
# 8546           Quality Control Analysts
# 6608               Pharmacy Technicians
# 9042     Project Management Specialists
# ...                                 ...
# 33860          Human Resources Managers
# 31497        Financial Risk Specialists
# 16783               Materials Engineers
# 15995    Business Intelligence Analysts
# 21647    Project Management Specialists
#
#                                                     task  similarity
# 43830  Contact customers to respond to inquiries or t...    0.927690
# 8545   Write technical reports or documentation, such...    0.912580
# 8546   Ensure that lab cleanliness and safety standar...    0.912580
# 6608   Clean and help maintain equipment or work area...    0.907098
# 9042   Develop or update project plans including info...    0.905668
# ...                                                  ...         ...
# 33860  Analyze and modify compensation and benefits p...    0.902398
# 31497  Inform financial decisions by analyzing financ...    0.902291
# 16783  Conduct training sessions on new material prod...    0.902256
# 15995  Maintain or update business intelligence tools...    0.901923
# 21647  Identify, review, or select vendors or consult...    0.901829
#
# [100 rows x 5 columns]
