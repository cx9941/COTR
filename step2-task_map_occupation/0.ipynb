# %%
import pandas as pd
all_data_list = pd.read_csv('../data/en/all_data.csv', sep='\t')
task_list = pd.read_csv('../data/en/task.csv', sep='\t')
task_list[['occupation']].drop_duplicates().to_csv('../data/en/task_occupation.csv', index=None)
task_list
# Out:
#                                 occupation  \
# 0                              Real Estate
# 1            Wellness and Fitness Services
# 2                              Restaurants
# 3                             Law Practice
# 4            Wellness and Fitness Services
# ...                                    ...
# 107492                        Law Practice
# 107493                Software Development
# 107494   Education Administration Programs
# 107495  Industrial Machinery Manufacturing
# 107496       IT Services and IT Consulting
#
#                                                      text
# 0       Job descriptionA leading real estate firm in N...
# 1       At Aspen Therapy and Wellness , we are committ...
# 2       The National Exemplar is accepting application...
# 3       Senior Associate Attorney - Elder Law / Trusts...
# 4       Looking for HVAC service tech with experience ...
# ...                                                   ...
# ...
