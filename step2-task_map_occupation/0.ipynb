# %%
import pandas as pd
task_list = pd.read_csv('../step1-task_list/task_art.csv', sep='\t')[['occupation', 'task']]
task_list.drop_duplicates().to_csv('../data/en/task_occupation.csv', index=None, sep='\t')
task_list
# Out:
#                                occupation  \
# 0                Accountants and Auditors
# 1                Accountants and Auditors
# 2                Accountants and Auditors
# 3                Accountants and Auditors
# 4                Accountants and Auditors
# ...                                   ...
# 18884  Zoologists and Wildlife Biologists
# 18885  Zoologists and Wildlife Biologists
# 18886  Zoologists and Wildlife Biologists
# 18887  Zoologists and Wildlife Biologists
# 18888  Zoologists and Wildlife Biologists
#
#                                                     task
# 0            Prepare detailed reports on audit findings.
# 1      Report to management about asset utilization a...
# 2      Collect and analyze data to detect deficient c...
# 3      Inspect account books and accounting systems f...
# 4      Supervise auditing of establishments, and dete...
# ...                                                  ...
# ...
