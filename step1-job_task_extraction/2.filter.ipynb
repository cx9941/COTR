# %%
import pandas as pd
dataset_name = 'jp'
# df = pd.read_csv(f'outputs/{dataset_name}/job_re_description.csv', sep='\t').groupby(['job_title', 'job_description']).agg(list).reset_index()
df = pd.read_parquet(f'outputs/{dataset_name}/job_re_description.parquet')
print('match jd num', len(df[df['len']>0]))
filter_df = df[df['len']>0]
print('num of filter job', len(filter_df))
print('num of extracted job task:', filter_df['len'].sum().item())
filter_df.to_excel(f'outputs/{dataset_name}/job_re_description_have_task.xlsx', index=None)
filter_df
# Out:
# match jd num 1439
# num of filter job 1439
# num of extracted job task: 4139
#                                             job_title  \
# 2176                    サービス開発エンジニア（自社開発SaaSプロダクトの開発）
# 1801         Salesforce用いたシステム開発や組み込み系開発に携わるシステムエンジニア
# 715   2021年3月創業/薬剤耐性問題を医療×デジタル技術で解決するスタートアップ企業/品質保証担当
# 2441                     データエンジニア/インターネット/Webサービス・ASP
# 167                             入力処理スタッフ【農業に関する入力処理業務
# ...                                               ...
# 2137                              人事・組織コンサルタント(責任者候補)
# 2136         【マネージャ候補】事業開発/キャッシュレス決済プラットフォーム「StarPay」
# 2135        プロダクト開発ゼネラルマネージャー/ゼネラルマネージャ候補　/　SaaSベンチャー
# 215                                 [1]事務・医療事務 [2]看護師
# 2142           Java/契約ライフサイクル管理システムのエンジニアリングマネージャー、開発
#
#                                         job_description  \
# 2176  【企業名】 株式会社ショーケース 【職種名】 サービス開発エンジニア（自社開発SaaSプロダ...
# 1801  コツコツと頑張ってきたあなたが、ありのままでいられる環境で、\nストレスなく成長していきませ...
# 715   応募資格について\n\n【必須資格・経験】\n・医療機器、医療機器プログラムの領域における品...
# ...

# %%
import os
filter_df = filter_df[['job_title', 'task']]
filter_df = filter_df.explode('task')
filter_df['task'] = filter_df['task'].apply(lambda x: x.split('。'))
filter_df = filter_df.explode('task')
filter_df = filter_df.drop_duplicates('task')
filter_df
# Out:
#                                      job_title  \
# 2176             サービス開発エンジニア（自社開発SaaSプロダクトの開発）
# 2176             サービス開発エンジニア（自社開発SaaSプロダクトの開発）
# 2176             サービス開発エンジニア（自社開発SaaSプロダクトの開発）
# 2176             サービス開発エンジニア（自社開発SaaSプロダクトの開発）
# 2176             サービス開発エンジニア（自社開発SaaSプロダクトの開発）
# ...                                        ...
# 2137                       人事・組織コンサルタント(責任者候補)
# 2137                       人事・組織コンサルタント(責任者候補)
# 2136  【マネージャ候補】事業開発/キャッシュレス決済プラットフォーム「StarPay」
# 215                          [1]事務・医療事務 [2]看護師
# 2142    Java/契約ライフサイクル管理システムのエンジニアリングマネージャー、開発
#
#                                                    task
# 2176  エンジニアのための取り組み】 ■Weekly Tech Talk 毎週火曜日に開催するエンジ...
# 2176                                すべてのエンジニアが対象で、参加は自由
# 2176           それぞれが参画するプロジェクトの情報や、課題・悩みを共有しながら助け合っています
# 2176         ■YUBUNE 「Weekly Tech Talk」の拡大版で、月1回開催しています
# 2176  毎月決まったテーマであり、エンジニアは持っている知識やノウハウをチーム内にシェアすることで、...
# ...                                                 ...
# ...

# %%
if 'jp' in dataset_name:
    filter_df['task_len'] = filter_df['task'].apply(len)
else:
    filter_df['task_len'] = filter_df['task'].apply(lambda x: len(x.split(' ')))
filter_df = filter_df.sort_values('task_len', ascending=False)
filter_df = filter_df[(filter_df['task_len']>3) & (filter_df['task_len']<50)]
filter_df
# Out:
#                                               job_title  \
# 2312  【横浜／第二新卒歓迎】炉装置の電気エンジニア　※月残業20H／転勤なし／創業80年以上の老舗...
# 2166  【北九州市】組込系エンジニア（車載・産業用装置・IoT関連等）◇案件保有数・エンジニア数トッ...
# 2158                      ITエンジニア／年休125日／リモート案件／独自の福利厚生
# 2154                      実践型研修でゼロから始められるITエンジニア／年休125日
# 2304   【東京・神奈川】【半導体エンジニア】◎60代以上活躍中◎スキルを活かして半導体業界へチャレンジ！
# ...                                                 ...
# 1777                       【完全在宅可】開発エンジニア/ソフトウェア・情報処理業界
# 658                                      医薬品の品質保証・品質管理職
# 806                              医療機器品質管理・品質保証(GQP・QMS)
# 1648  ゲーム開発クライアントエンジニア|メタバース(Roblox)(未経験者)/モバイル/アプリサービス
# 2052                    【ポテンシャル】PdM/インターネット/Webサービス・ASP
#
#                                                    task  task_len
# 2312  横浜／第二新卒歓迎】炉装置の電気エンジニア ※月残業20H／転勤なし／創業80年以上の老舗メーカー        49
# 2166  北九州市】組込系エンジニア（車載・産業用装置・IoT関連等）◇案件保有数・エンジニア数トップクラス        49
# 2158  丁寧な研修で着実に成長！】豊富なプロジェクトから希望やスキルに応じてキャリアを築いていきましょう！        49
# ...

# %%
if not os.path.exists(f'results/{dataset_name}'):
    os.makedirs(f'results/{dataset_name}')
filter_df.to_csv(f'results/{dataset_name}/job_re_description.csv', index=None, sep='\t')
filter_df.to_excel(f'results/{dataset_name}/{dataset_name}-job_re_description.xlsx', index=None)
