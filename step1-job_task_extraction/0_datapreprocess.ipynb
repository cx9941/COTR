# %%
import os
import pandas as pd
dataset_name = 'jp'
df = pd.read_csv(f'../data/{dataset_name}/job_description.csv', sep='\t')
df = df[df['job_description'].apply(type)==type('')]
df = df[df['job_description'].apply(len)> 0]
df = df.drop_duplicates('job_description')
df.columns = ['job_title', 'job_description']
if not os.path.exists(f'data/{dataset_name}'):
    os.makedirs(f'data/{dataset_name}')
df.to_csv(f'data/{dataset_name}/job_description.csv', index=None, sep='\t')
df
# Out:
#                                               job_title  \
# 0                                              データ入力・修正
# 1                             SNS運用データ入力/週払いのできるオフィスワーク
# 2                                        PCデータ入力(SNS運用)
# 5                         恋愛シミュレーションゲームのデータ入力/企画・事務・管理系
# 6                                                 データ入力
# ...                                                 ...
# 3971                        AIを活用したDX施策の企画・推進　/　大手メガバンク
# 3973                                            データ解析技術
# 3980  シニアデータサイエンティスト(Strategic AI Group/エンプラの大規模データの...
# 3982                               データアナリスト・データサイエンティスト
# 3984  【スペシャリスト】テクノロジーエンジニア(AI関連プロダクト、サービスの企画、設計、改善およ...
#
#                                         job_description
# 0     データ入力・修正\n朝１０時開始！みんな未経験から始めてます。高速バス料金比較サイトのデータ...
# 1     \n \n  週払いOK！勤務中の飲食自由働きやすさ抜群！ピアス・ネイル・タトゥ・髪色完全自...
# 2     ★新規事業立ち上げ★オープニングメンバー！服装/髪色/ピアス/タトゥ自由◎\n\n\n駅チカ...
# 5     恋愛シミュレーションゲームのデータ入力(未経験歓迎) 服装自由/週2日×1日3時間からOK ...
# 6     \n \n  未経験者歓迎PCのタイピングができればOKピアス/ネイル/タトゥ/週払い/完全...
# ...                                                 ...
# 3971  <募集要項>\n\n【職務内容】\n【業務内容】AI、機械学習の金融業務適用に向けて、企画、...
# 3973  半導体デバイス製造のビッグデータ解析\nプログラミング・AI・データ解析・ITに興味がある方...
# 3980  【年収】: 900~2,000万円  【仕事内容】: 既に約30名の優秀なデータサイエンティ...
# 3982  みずほ第一フィナンシャルテクノロジー株式会社  【東京】数理コンサルティング・データアナリテ...
# 3984  【年収】: 600~800万円  【仕事内容】: ・クラウドサーバ上のAI実行基盤の設計、開...
#
# [2703 rows x 2 columns]

# %%
import re
 
# 示例字符串
text = "IP: 192.168.1.1 Port: 80"
 
# 正则表达式
pattern = ":"
 
# 使用正则表达式进行匹配
matches = re.findall(pattern, text)
 
# 输出匹配结果
for match in matches:
    print(match)
# Out:
# :
# :
