# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import rcParams
from matplotlib.font_manager import FontProperties

x = [0, 1, 2, 3, 4, 5]
y1_random = [55, 56, 55, 56, 59, 57]
y2_random = [54, 57, 56, 55, 56, 55]

y1_entropy = [55, 55, 56, 57, 56, 58]
y2_entropy = [54, 54, 54, 55, 54, 55]

y1_cal = [55, 55, 56, 57, 58, 60]
y2_cal = [54, 55, 55, 56, 57, 58]
fig, axs = plt.subplots(1, 3, figsize=(12, 3))

# # 加载并设置全局字体
# font_path = '/data/chenxi/research/conference/TMIS/COTR/appendix/arial/ARIAL.TTF'  # 替换为你字体的路径
# arial_font = FontProperties(fname=font_path)

axs[0].plot(x, y1_random, 'o-', label='COTR-SRM(Random)', color='#B86D42', markersize=8)  
axs[0].plot(x, y2_random, '^-', label='COTR-SRM w/o pairwise loss', color='#46835D', markersize=8)  
axs[1].plot(x, y1_entropy, 'o-', label='COTR-SRM(Entropy)', color='#B86D42', markersize=8)  
axs[1].plot(x, y2_entropy, '^-', label='COTR-SRM w/o pairwise loss', color='#46835D', markersize=8)  
axs[2].plot(x, y1_cal, 'o-', label='COTR-SRM(CAL)', color='#B86D42', markersize=8)  
axs[2].plot(x, y2_cal, '^-', label='COTR-SRM w/o pairwise loss', color='#46835D', markersize=8)  
for ax in axs:
    ax.legend(loc='upper left', prop={'size': 10})
    ax.grid(axis='y',  linestyle='--') 
    ax.set_xticks(x)
    ax.set_yticks(np.arange(54, 61, 1))
    ax.tick_params(axis='x', length=0)  # Remove x-axis tick marks
    ax.tick_params(axis='y', length=0)  # Remove y-axis tick marks

plt.tight_layout()
plt.savefig('temp.pdf')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = [0, 1, 2, 3, 4, 5]
y1_random = [86, 87, 88, 89, 90, 91]
y2_random = [85, 86, 87, 88, 89, 90]
y3_random = [85, 85, 87, 87, 88, 89]

y1_entropy = [86, 87, 88, 89, 90, 91]
y2_entropy = [85, 86, 87, 88, 89, 90]
y3_entropy = [85, 85, 87, 87, 88, 89]

y1_cal = [86, 87, 88, 89, 90, 91]
y2_cal = [85, 86, 87, 88, 89, 90]
y3_cal = [85, 85, 87, 87, 88, 89]

fig, axs = plt.subplots(1, 3, figsize=(12, 3))

axs[0].plot(x, y1_random, 'o-', label='COTR-SRM(Random)', color='#D67C59', markersize=8)  
axs[0].plot(x, y2_random, '^-', label='COTR-SRM w/o pairwise loss', color='#468C5B', markersize=8)  
axs[0].plot(x, y3_random, 'D-', label='COTR-SRM w/o pairwise loss & CEDA', color='#466D8C', markersize=8)  

axs[1].plot(x, y1_entropy, 'o-', label='COTR-SRM(Entropy)', color='#D67C59', markersize=8)  
axs[1].plot(x, y2_entropy, '^-', label='COTR-SRM w/o pairwise loss', color='#468C5B', markersize=8)  
axs[1].plot(x, y3_entropy, 'D-', label='COTR-SRM w/o pairwise loss & CEDA', color='#466D8C', markersize=8)  

axs[2].plot(x, y1_cal, 'o-', label='COTR-SRM(CAL)', color='#D67C59', markersize=8)  
axs[2].plot(x, y2_cal, '^-', label='COTR-SRM w/o pairwise loss', color='#468C5B', markersize=8)  
axs[2].plot(x, y3_cal, 'D-', label='COTR-SRM w/o pairwise loss & CEDA', color='#466D8C', markersize=8)  

for ax in axs:
    ax.legend(loc='upper left')
    ax.grid(axis='y', linestyle='--') 
    ax.set_xticks(x)
    ax.set_yticks(np.arange(85, 93, 1))
    ax.tick_params(axis='y', length=0) 
    ax.tick_params(axis='x', length=0) 


plt.tight_layout()
plt.savefig('temp.pdf')
plt.show()
