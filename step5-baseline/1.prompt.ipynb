# %%
import pandas as pd
from utils import gen

dataset_name = 'eu'
final_ans = pd.read_csv(f'../step4-llm_select/results/{dataset_name}/{dataset_name}_gpt-llm-bert.csv')
# final_ans.to_csv(f'data/inputs/{dataset_name}.csv', sep='\t', index=None)
final_ans['bert_task'] = final_ans['bert_task'].apply(eval)
final_ans = final_ans[['job_title', 'job_description', 'bert_task']]
for i in range(100):
    final_ans[f"task{i}"] = final_ans['bert_task'].apply(lambda x: x[i])
final_ans = final_ans.drop('bert_task', axis=1)
final_ans['prompt'] = final_ans.apply(lambda x: gen(x, dataset_name), axis=1)
final_ans
# Out:
# /tmp/ipykernel_2518254/2052464327.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_ans[f"task{i}"] = final_ans['bert_task'].apply(lambda x: x[i])
# /tmp/ipykernel_2518254/2052464327.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_ans[f"task{i}"] = final_ans['bert_task'].apply(lambda x: x[i])
# /tmp/ipykernel_2518254/2052464327.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_ans['prompt'] = final_ans.apply(lambda x: gen(x, dataset_name), axis=1)
#                              job_title  \
# 0              Brand Marketing Manager
# 1                      Product Manager
# 2       Director Business Development
# 3                 Senior Brand Manager
# 4    Advanced Surgery Account Manager
# ..                                 ...
# 96          Regulatory Affairs Manager
# 97           Senior RA / QA Specialist
# 98              QA Validation Engineer
# 99                Senior Statistician
# 100             Senior Account Manager
#
#                                        job_description  \
# 0    Develop and implement marketing strategy for p...
# 1    Develop the annual marketing investment plans ...
# 2    * Work with Marketing to develop and implement...
# 3    Developing and leading the brand and marketing...
# 4    Collaborate closely with Marketing on how to b...
# ..                                                 ...
# 96   * Liaising with and maintaining records of sub...
# 97   * Work on the polish market registration process.
# 98   * You will have to pro-actively identify poten...
# 99   -Provides support to the complex study analysi...
# 100  Provide strategic, creative and tactical input...
#
#                                                  task0  \
# 0          Analyze data to inform personnel decisions.
# 1    Develop content for sales presentations or oth...
# 2               Develop marketing plans or strategies.
# 3               Develop marketing plans or strategies.
# 4    Inform the public about policies, services or ...
# ..                                                 ...
# 96                       Write informational material.
# 97   Customize financial products or services to me...
# 98   Customize financial products or services to me...
# 99   Provide technical information or assistance to...
# 100  Inform the public about policies, services or ...
#
#                                                  task1  \
# 0    Develop content for sales presentations or oth...
# 1    Advise customers on technical or procedural is...
# 2    Direct sales, marketing, or customer service a...
# 3    Direct sales, marketing, or customer service a...
# 4               Develop marketing plans or strategies.
# ..                                                 ...
# 96            Develop promotional strategies or plans.
# 97   Examine marketing materials to ensure complian...
# 98   Identify opportunities to improve operational ...
# 99   Direct organizational operations, projects, or...
# 100             Develop marketing plans or strategies.
#
#                                                  task2  \
# 0    Confer with organizational members to accompli...
# 1    Communicate organizational policies and proced...
# 2               Develop business or market strategies.
# 3               Develop business or market strategies.
# 4    Gather customer or product information to dete...
# ..                                                 ...
# 96   Confer with personnel to coordinate business o...
# 97   Provide technical support for software mainten...
# 98   Develop safety standards, policies, or procedu...
# 99                              Manage guest services.
# 100                 Advise others on logistics topics.
#
#                                                  task3  \
# 0          Explain financial information to customers.
# 1          Explain financial information to customers.
# 2    Inform the public about policies, services or ...
# 3    Inform the public about policies, services or ...
# 4                   Advise others on logistics topics.
# ..                                                 ...
# 96                             Negotiate for services.
# 97   Provide recommendations to others about comput...
# 98                   Monitor organizational processes.
# 99   Correspond with customers to answer questions ...
# 100  Study product information to acquire professio...
#
#                                                  task4  \
# 0                 Develop financial or business plans.
# 1    Measure effectiveness of business strategies o...
# 2       Coordinate activities of production personnel.
# 3          Interpret financial information for others.
# 4    Study product information to acquire professio...
# ..                                                 ...
# 96         Supervise information technology personnel.
# 97   Maintain current knowledge related to work act...
# 98                              Evaluate data quality.
# 99   Answer customer questions about goods or servi...
# 100  Gather customer or product information to dete...
#
#                                                  task5  \
# 0               Develop business or market strategies.
# 1    Communicate organizational information to cust...
# 2                 Develop financial or business plans.
# 3                 Develop financial or business plans.
# 4    Obtain personal or financial information about...
# ..                                                 ...
# 96         Coordinate reporting or editing activities.
# 97                           Determine resource needs.
# 98   Provide information about landscaping services...
# 99    Collaborate with others in marketing activities.
# 100        Coordinate reporting or editing activities.
#
#                                                  task6  \
# 0       Gather organizational performance information.
# 1     Establish organizational guidelines or policies.
# 2          Interpret financial information for others.
# 3       Coordinate activities of production personnel.
# 4    Negotiate contracts with clients or service pr...
# ..                                                 ...
# 96   Study product information to acquire professio...
# 97                    Identify environmental concerns.
# 98             Confer with clients to determine needs.
# 99         Develop organizational goals or objectives.
# 100  Negotiate contracts with clients or service pr...
#
#                                                  task7  ...  \
# 0           Manage organizational security activities.  ...
# 1                         Prepare operational budgets.  ...
# 2    Research relevant legal materials to aid decis...  ...
# 3    Research relevant legal materials to aid decis...  ...
# 4          Interpret financial information for others.  ...
# ..                                                 ...  ...
# 96   Inform the public about policies, services or ...  ...
# 97   Provide information about landscaping services...  ...
# 98   Collaborate with technical specialists to reso...  ...
# 99                Develop financial plans for clients.  ...
# 100  Obtain personal or financial information about...  ...
#
#                                                 task91  \
# 0                        Analyze market research data.
# 1    Provide customers with general information or ...
# 2     Calculate numerical data for medical activities.
# 3                    Draft legislation or regulations.
# 4          Develop organizational goals or objectives.
# ..                                                 ...
# 96   Research impacts of environmental conservation...
# 97              Establish business management methods.
# 98    Design healthcare-related software applications.
# 99                       Process healthcare paperwork.
# 100    Coordinate regulatory documentation activities.
#
#                                                 task92  \
# 0             Resolve customer complaints or problems.
# 1    Apply knowledge or research findings to addres...
# 2    Advise others on business or operational matters.
# 3    Promote environmental sustainability or conser...
# 4    Analyze jobs using observation, survey, or int...
# ..                                                 ...
# 96     Adjust positions of patients on beds or tables.
# 97   Warn individuals about rule violations or safe...
# 98                Monitor market conditions or trends.
# 99   Provide first aid or rescue assistance in emer...
# 100  Protect patients or staff members using safety...
#
#                                                 task93  \
# 0    Obtain personal or financial information about...
# 1            Refer customers to appropriate personnel.
# 2    Prepare research or technical reports on envir...
# 3                          Coordinate sales campaigns.
# 4    Protect patients or staff members using safety...
# ..                                                 ...
# 96   Represent the organization in external relations.
# 97              Discuss designs or plans with clients.
# 98   Design research studies to obtain scientific i...
# 99       Conduct hearings to investigate legal issues.
# 100   Establish organizational guidelines or policies.
#
#                                                 task94  \
# 0    Develop sustainable organizational policies or...
# 1    Advise customers on the use of products or ser...
# 2                              Negotiate for services.
# 3                   Manage human resources activities.
# 4     Establish organizational guidelines or policies.
# ..                                                 ...
# 96   Conduct scientific research of organizational ...
# 97       Arrange services or reservations for patrons.
# 98   Develop sustainable business strategies or pra...
# 99   Discuss business strategies, practices, or pol...
# 100  Analyze jobs using observation, survey, or int...
#
#                                                 task95  \
# 0    Share sales-related or market information with...
# 1    Answer telephones to direct calls or provide i...
# 2                         Direct financial operations.
# 3    Advise others on business or operational matters.
# 4    Measure effectiveness of business strategies o...
# ..                                                 ...
# 96   Liaise between departments or other groups to ...
# 97                  Maintain public order or security.
# 98            Monitor flow of cash or other resources.
# 99   Complete documentation required by programs or...
# 100     Manage content of broadcasts or presentations.
#
#                                                 task96  \
# 0       Coordinate enforcement of laws or regulations.
# 1    Coordinate safety or regulatory compliance act...
# 2                    Draft legislation or regulations.
# 3                      Develop program goals or plans.
# 4       Manage content of broadcasts or presentations.
# ..                                                 ...
# 96          Write advertising or promotional material.
# 97          Assess compliance with environmental laws.
# 98   Develop environmental remediation or protectio...
# 99           Refer customers to appropriate personnel.
# 100  Measure effectiveness of business strategies o...
#
#                                                 task97  \
# 0    Apply knowledge or research findings to addres...
# 1                          Prepare proposal documents.
# 2                 Gather information for news stories.
# 3           Maintain knowledge of business operations.
# 4    Record information from meetings or other form...
# ..                                                 ...
# 96   Prepare scientific or technical reports or pre...
# 97   Advise others on farming or forestry operation...
# 98                  Record sales or transactions data.
# 99         Interpret financial information for others.
# 100  Record information from meetings or other form...
#
#                                                 task98  \
# 0             Inform others about laws or regulations.
# 1                Communicate with government agencies.
# 2     Maintain regulatory or compliance documentation.
# 3        Prepare legal or investigatory documentation.
# 4    Develop content for sales presentations or oth...
# ..                                                 ...
# 96           Arrange collective bargaining agreements.
# 97      Provide notifications to customers or patrons.
# 98            Identify sustainable business practices.
# 99                      Make decisions in legal cases.
# 100  Direct organizational operations, projects, or...
#
#                                                 task99  \
# 0    Study product information to acquire professio...
# 1    Coordinate operational activities with externa...
# 2    Discuss production content and progress with o...
# 3     Calculate numerical data for medical activities.
# 4            Monitor recreational facility operations.
# ..                                                 ...
# 96               Prepare medical reports or documents.
# 97   Document organizational or operational procedu...
# 98   Implement organizational process or policy cha...
# 99   Document information related to legal proceedi...
# 100  Develop content for sales presentations or oth...
#
#                                                 prompt
# 0    Now given 100 specific task descriptions and 1...
# 1    Now given 100 specific task descriptions and 1...
# 2    Now given 100 specific task descriptions and 1...
# 3    Now given 100 specific task descriptions and 1...
# 4    Now given 100 specific task descriptions and 1...
# ..                                                 ...
# 96   Now given 100 specific task descriptions and 1...
# 97   Now given 100 specific task descriptions and 1...
# 98   Now given 100 specific task descriptions and 1...
# 99   Now given 100 specific task descriptions and 1...
# 100  Now given 100 specific task descriptions and 1...
#
# [101 rows x 103 columns]

# %%
import os
if not os.path.exists(f"data/{dataset_name}/inputs/"):
    os.makedirs(f"data/{dataset_name}/inputs/")
for i in range(len(final_ans)):
    with open(f"data/{dataset_name}/inputs/{i}.txt", 'w') as w:
        w.write(final_ans['prompt'][i])
