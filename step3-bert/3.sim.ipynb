# %%
import torch
dataset_name = 'eu'
occupation_embedding = torch.load(f'outputs/{dataset_name}/occupation_embedding.pt')
title_embedding = torch.load(f'outputs/{dataset_name}/title_embedding.pt')
# Out:
# /tmp/ipykernel_2365319/957920525.py:3: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   occupation_embedding = torch.load(f'outputs/{dataset_name}/occupation_embedding.pt')
# /tmp/ipykernel_2365319/957920525.py:4: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   title_embedding = torch.load(f'outputs/{dataset_name}/title_embedding.pt')

# %%
import pandas as pd
import os
occupation = pd.read_csv(f'data/{dataset_name}/occupation.csv', sep='\t')
title = pd.read_csv(f'data/{dataset_name}/title.csv', sep='\t')

# %%
from utils import cosine_similarity_matrix
similarity_matrix = cosine_similarity_matrix(title_embedding, occupation_embedding)
topk_indices = torch.topk(similarity_matrix, dim=-1,k=10).indices
topk_value = torch.topk(similarity_matrix, dim=-1,k=10).values

# %%
import pandas as pd
topk_task = pd.DataFrame(topk_indices.numpy())
topk_values = pd.DataFrame(topk_value.numpy())

# %%
for col in topk_task.columns:
    title[f"occupation{col}"] = topk_task[col].apply(lambda x: occupation['occupation'][x]) 
    title[f"occupation{col}_sim"] = topk_values[col] 
title.to_csv(f'outputs/{dataset_name}/title_top10_occupation.csv', index=None, sep='\t')
title.head()
# Out:
#                                      title                       occupation0  \
# 0     Senior / Medical Writer (Regulatory)    Clinical Research Coordinators
# 1                   Manager of Biometrics        Regulatory Affairs Managers
# 2  Field Service Engineer | Chromatography            Mechatronics Engineers
# 3       Data Manager of Project Management  Quality Control Systems Managers
# 4                 Strategic Market Analyst    Business Intelligence Analysts
#
#    occupation0_sim                     occupation1  occupation1_sim  \
# 0         0.828742          Pediatricians, General         0.826528
# 1         0.809853  Clinical Research Coordinators         0.802509
# 2         0.804246            Chemical Technicians         0.801972
# 3         0.879237    Business Continuity Planners         0.872607
# 4         0.907234      Financial Risk Specialists         0.903327
#
#                                  occupation2  occupation2_sim  \
# 0             Health Informatics Specialists         0.814939
# 1                   Quality Control Analysts         0.797477
# 2                       Robotics Technicians         0.800028
# 3  Computer and Information Systems Managers         0.868426
# 4                         Logistics Analysts         0.900027
#
#                                      occupation3  occupation3_sim  \
# 0                     Clinical Nurse Specialists         0.811365
# 1  Directors, Religious Activities and Education         0.794687
# 2                       Food Science Technicians         0.799695
# 3        Information Technology Project Managers         0.865657
# 4              Financial and Investment Analysts         0.891896
#
#                          occupation4  ...  \
# 0            Patient Representatives  ...
# 1     Regulatory Affairs Specialists  ...
# 2  Ophthalmic Laboratory Technicians  ...
# 3     Project Management Specialists  ...
# 4           Investment Fund Managers  ...
#
#                                    occupation5 occupation5_sim  \
# 0         Advanced Practice Psychiatric Nurses        0.805827
# 1         Training and Development Specialists        0.790944
# 2                       Biological Technicians        0.797652
# 3  Network and Computer Systems Administrators        0.852566
# 4                          Management Analysts        0.887748
#
#                               occupation6 occupation6_sim  \
# 0             Regulatory Affairs Managers        0.803427
# 1  Architectural and Engineering Managers        0.789458
# 2                   Photonics Technicians        0.795842
# 3            Data Warehousing Specialists        0.852560
# 4            Operations Research Analysts        0.882788
#
#                       occupation7 occupation7_sim  \
# 0    Public Relations Specialists        0.803179
# 1  Project Management Specialists        0.787801
# 2            Avionics Technicians        0.792499
# 3        Quality Control Analysts        0.848980
# 4     Regulatory Affairs Managers        0.881212
#
#                                          occupation8 occupation8_sim  \
# 0                       Health Education Specialists        0.802627
# 1                  Training and Development Managers        0.787527
# 2  Bus and Truck Mechanics and Diesel Engine Spec...        0.792474
# 3                Web and Digital Interface Designers        0.842598
# 4  Market Research Analysts and Marketing Special...        0.881093
#
#                             occupation9 occupation9_sim
# 0  Medical and Health Services Managers        0.801496
# 1  Medical and Health Services Managers        0.785085
# 2                   Traffic Technicians        0.790977
# 3       General and Operations Managers        0.838922
# 4              Quality Control Analysts        0.880713
#
# [5 rows x 21 columns]
