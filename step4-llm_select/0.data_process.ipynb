# %%
import pandas as pd
import os

dataset_name = 'eu'
df = pd.read_excel(f'../step3-bert_recall/CuBERT/results/{dataset_name}/2e-05_32_0.8/{dataset_name}.xlsx')
for seed in range(5, 10):
    if not os.path.exists(f'data/{dataset_name}/seed{seed}/input0'):
        os.makedirs(f'data/{dataset_name}/seed{seed}/input0')
    df.to_csv(f'data/{dataset_name}/seed{seed}/input0/task_candidate.csv', index=None, sep='\t')
df
# Out:
#                                          job_title  \
# 0                          Start up Specialist II
# 1            Senior Regulatory Affairs CMC Manager
# 2                             Engineering Director
# 3                          Key Account Specialist
# 4           Artwork and Packaging Project Manager
# ...                                            ...
# 6365                 Senior Statistical Programmer
# 6366  Clinical Support Worker (12 month contract)
# 6367          Quality Engineer / complain handling
# 6368                       Clinical Study Manager
# 6369                                  CSV Engineer
#
#                                         job_description  \
# 0     Provide accurate projections and timelines to ...
# 1     Translation and interpretation of the country ...
# 2     4. As a member of the Site Leadership Team, pr...
# 3     Covering the South East region you will be res...
# 4     -Be responsible for tracking and real-time tra...
# ...
