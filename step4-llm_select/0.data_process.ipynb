# %%
import pandas as pd
import os

dataset_name = 'jp'
df = pd.read_excel(f'../step3-bert_recall/CuBERT/results/{dataset_name}/2e-05_32_0.8/{dataset_name}.xlsx')
for seed in range(5):
    if not os.path.exists(f'data/{dataset_name}/seed{seed}/input0'):
        os.makedirs(f'data/{dataset_name}/seed{seed}/input0')
    df.to_csv(f'data/{dataset_name}/seed{seed}/input0/task_candidate.csv', index=None, sep='\t')
df
# Out:
#                                    job_title  \
# 0          【プロダクトマネージャー】/インターネット/Webサービス・ASP
# 1                            データ入力・一般事務スタッフS
# 2                            Go/BaaSプロダクトの開発
# 3             【共創プロダクトマネージャー】マネーフォワードエックス_東京
# 4     デザイン業務(グラフィックデザイン、DTPデザイン、webデザイン)(石川)
# ...                                      ...
# 2963                                    品質保証
# 2964                                品質保証(機械)
# 2965                       取引先の品質保証体制監査と改善指導
# 2966         税理士事務所で会計入力事務からスタートする長期インターンシップ
# 2967                               産婦人科の医療事務
#
#                                         job_description  \
# 0     まちの回遊性向上を図れるデジタルスタンプラリーやデジタルクーポン機能、地域経済を活性化させる...
# 1     お客様（生命保険の加入者様）から提出された各種書類に不備（  記載もれ、書類の不足等）が無い...
# 2     プロダクトマネージャが提示するプロダクトのビジョンや要件を、主に技術的な観点からブレイクダウ...
# 3     様々な局面から参画いただくことがありますが、最大のスコープとしては、営業支援から始まり、企画...
# 4     ロゴやパッケージ、会社案内、社内報、広告デザイン、カタログ/リーフレットなどの企画からDTP...
# ...                                                 ...
# 2963                                             監査対応など
# 2964                                             データの分析
# 2965                                             お客様に安全
# 2966                                             決算業務補助
# 2967                                             診療報酬請求
#
#                                                    text  \
# 0     【プロダクトマネージャー】/インターネット/Webサービス・ASP-まちの回遊性向上を図れる...
# 1     データ入力・一般事務スタッフS-お客様（生命保険の加入者様）から提出された各種書類に不備（ ...
# 2     Go/BaaSプロダクトの開発-プロダクトマネージャが提示するプロダクトのビジョンや要件を、...
# 3     【共創プロダクトマネージャー】マネーフォワードエックス_東京-様々な局面から参画いただくこと...
# 4     デザイン業務(グラフィックデザイン、DTPデザイン、webデザイン)(石川)-ロゴやパッケー...
# ...                                                 ...
# 2963                                        品質保証-監査対応など
# 2964                                    品質保証(機械)-データの分析
# 2965                           取引先の品質保証体制監査と改善指導-お客様に安全
# 2966             税理士事務所で会計入力事務からスタートする長期インターンシップ-決算業務補助
# 2967                                   産婦人科の医療事務-診療報酬請求
#
#                                   task0  \
# 0        コンピュータ機器やハードウェアの使用方法を他の人に教えます。
# 1     製品やサービスの設計や技術的特徴について技術担当者と話し合います。
# 2           ライブラリまたはアーカイブ データベースを開発します。
# 3            調査レポートまたはインシデントレポートを準備します。
# 4           デジタル文書、データ、または画像をフォーマットします。
# ...                                 ...
# 2963     ヘルスケア関連のソフトウェア アプリケーションを設計します。
# 2964              組織活動を評価するための手順を開発します。
# 2965           データベースのパラメータまたは仕様を開発します。
# 2966             マーケティング活動において他者と協力します。
# 2967                           がん治療を施す。
#
#                                            task1  \
# 0             コンピューターで生成されたグラフィックやアニメーションを作成します。
# 1                 コンピュータ機器やハードウェアの使用方法を他の人に教えます。
# 2                            マーケティング計画や戦略を策定します。
# 3                       人事ポリシーまたは人事慣行の有効性を評価します。
# 4                    予測データを分析してビジネス上の意思決定を改善します。
# ...                                          ...
# 2963  科学的または技術的な使用を目的としたソフトウェアまたはアプリケーションを開発します。
# 2964                        医療用または歯科用補助機器を修理します。
# 2965                                家畜管理方法を研究する。
# 2966                         市民プロジェクトや公共政策を評価する。
# 2967                          医療現場における事務業務を行います。
#
#                                    task2  \
# 0      製品やサービスの設計や技術的特徴について技術担当者と話し合います。
# 1     コンピューターで生成されたグラフィックやアニメーションを作成します。
# 2                   ビジネス戦略または市場戦略を策定します。
# 3      財務記録を検査して、ポリシーや規制に準拠していることを確認します。
# 4                      エネルギー生産データを評価します。
# ...                                  ...
# 2963                     労働時間や活動を文書化します。
# 2964           口、歯、歯茎、または関連する顔の構造を検査します。
# 2965          スタッフのスケジュールや仕事の割り当てを準備します。
# 2966                    社会問題に関する調査を実施する。
# 2967                         治療や療法を処方する。
#
#                                          task3  \
# 0              プロセスや製品を改善する方法について他の人にアドバイスします。
# 1     エンジニアリングや設計活動に関連する人間のパフォーマンスや健康要因を研究します。
# 2                              財務情報の正確性を確認します。
# 3                         ビジネス戦略または市場戦略を策定します。
# 4             コンピュータのハードウェアに関する推奨事項を他の人に提供します。
# ...                                        ...
# 2963                      運用データまたは生産データを記録します。
# 2964                                航空機のパイロット。
# 2965                              生徒の成績を監視します。
# 2966                                生活スキルを教える。
# 2967                  患者または治療データをコンピュータに入力します。
#
#                                task4                               task5  \
# 0                         テストを準備します。                  財務計画または事業計画を策定します。
# 1     安全で健康的な機器や設備については他の人に相談してください。                グリーンテクノロジーの特性を評価します。
# 2                  環境条件に関する情報を記録します。         人事に関するトピックについて他の人にアドバイスします。
# 3                        税金情報を計算します。                   法律事項に関する情報を記録します。
# 4                       手続き書類を準備します。            コンピュータのハードウェアをインストールします。
# ...                              ...                                 ...
# 2963             他の人に操作手順をトレーニングします。            顧客に製品やサービスの技術的な情報を説明します。
# 2964         製品、プロセス、または手順の標準を確立します。                          ゴミを取り除きます。
# 2965          技術情報やサポートを一般の人々に提供します。              プログラムまたはサービスの計画を作成します。
# 2966   学業やキャリアに関する問題について学生にアドバイスします。  トレーニング プログラム、インストラクター、または教材を評価します。
# 2967               医療処置のプロトコルを決定します。                            病状を診断する。
#
#                                      task6  ...  \
# 0                   グリーンテクノロジーの設計要件を分析します。  ...
# 1     製品、手順、ポリシーについてクライアントとコミュニケーションをとります。  ...
# 2                 人事ポリシーまたは人事慣行の有効性を評価します。  ...
# 3                          財務情報の正確性を確認します。  ...
# 4              プロジェクト データを分析して仕様や要件を決定します。  ...
# ...                                    ...  ...
# 2963                 データベースのパフォーマンスを評価します。  ...
# 2964        不動産や施設を規制に準拠させるために必要な措置を特定します。  ...
# 2965               違法または危険な物品がないか個人を捜索します。  ...
# 2966                            教育政策を策定する。  ...
# 2967                   医療データを分析して死因を特定します。  ...
#
#                                   task90                             task91  \
# 0                        サウンド入力をミックスします。     ヘルスケア関連のソフトウェア アプリケーションを設計します。
# 1               手順に従って法医学的または法的証拠を処理します。                   医療レポートや文書を準備します。
# 2     環境修復、グリーンエネルギー、再生可能資源に関する契約を交渉します。          専門知識を維持するために専門文献をレビューします。
# 3                  業務活動に関連する最新の知識を維持します。  法律または規制の遵守に関する事項について他の人にアドバイスします。
# 4                       販売やその他の取引を処理します。          他の人と協議して、業務活動を実行または調整します。
# ...                                  ...                                ...
# 2963                         交通信号を監視します。             クライアントの状態や進捗状況を文書化します。
# 2964                         人事活動を管理します。                    植物や作物の品質を評価します。
# 2965                製品またはプロセスの有用性を評価します。                     患者の日常活動を支援します。
# 2966                     スタッフをトレーニングします。                社会福祉プログラムの記録を維持します。
# 2967                       テスト結果を文書化します。               画像やその他の視覚的な表示を作成します。
#
#                              task92                                  task93  \
# 0                  産業事故や輸送事故を調査します。      クライアントが必要なサービスやリソースを入手できるように支援します。
# 1              水文学的特徴またはプロセスを研究します。              経営に関するテーマについて人材をトレーニングします。
# 2      健康と安全に関する問題について他の人にアドバイスします。                             人事情報を記録します。
# 3      ビジネスや運営上の問題について他の人にアドバイスします。                       業務運営に関する知識を維持します。
# 4          情報技術プロジェクトのリソース要件を特定します。                        事故を調査して原因を究明します。
# ...                             ...                                     ...
# 2963         造園サービスや費用に関する情報を提供します。          教育上のニーズや進捗状況を評価するためにテストを実施します。
# 2964          運用データの定量的な障害分析を実施します。  運用またはプロジェクトで使用するツール、機器、またはテクノロジを選択します。
# 2965                  ビジネス指標を監視します。                             潜在顧客を特定します。
# 2966             財務記録またはプロセスを検査します。                         専門知識をアップデートします。
# 2967  患者データを分析して、患者のニーズや治療目標を決定します。                     設計またはプロセスの改善を実施します。
#
#                                  task94                                task95  \
# 0                   活動を承認するための文書を取得します。                    技術文書を確認して作業を計画します。
# 1                 組織のメンバーと協議して業務を遂行します。                       新しい技術や方法を評価します。
# 2                 許可証またはライセンスの文書を準備します。                        専門分野における研究テーマ。
# 3                      プログラムの有効性を評価します。            教育や職業上の問題についてクライアントに助言します。
# 4                ビジネスまたは財務情報システムを開発します。       顧客のニーズに合わせて金融商品やサービスをカスタマイズします。
# ...                                 ...                                   ...
# 2963                     警告または告発を発行します。  製品、手順、ポリシーについてクライアントとコミュニケーションをとります。
# 2964  サプライヤー、請負業者、顧客、または他の部門との活動を調整します。                 材料、機器、その他のリソースを購入します。
# 2965                  指導資料や図書館資料を配布します。            患者を他の医療従事者または医療リソースに紹介します。
# 2966                    アーカイブデータを収集します。              ニュースや娯楽の目的で他の人にインタビューする。
# 2967                   高度な生命維持技術を実装します。               健康上の問題を検出するために患者を監視します。
#
#                              task96                                 task97  \
# 0     作業割り当てを実行するための情報または指示を受け取ります。                        学校や生徒の活動を監督します。
# 1     高度なエンジニアリング設計やアプリケーションを研究します。                           健康管理の授業を教える。
# 2             クラスやコミュニティイベントを主導します。         従業員、顧客、その他の人にインタビューして情報を収集します。
# 3                   法的な事件に関して決定を下す。                   顧客情報またはサービス記録を維持します。
# 4             地質学的または地理学的データを分析します。  電話や双方向無線を使用して、事故や緊急事態に関する情報を担当者に伝えます。
# ...                             ...                                    ...
# 2963        マネージャーと協議して運用上の決定を下します。  電話や双方向無線を使用して、事故や緊急事態に関する情報を担当者に伝えます。
# 2964     化学処理または水処理システムまたは装置を操作します。                           現在の傾向を監視します。
# 2965   医療活動または手術が基準を満たしていることを確認します。                              直接的な犯罪捜査。
# 2966  グリーンテクノロジーへの投資に関連するリスクを分析します。                   商品やサービスに対する代金を徴収します。
# 2967            X 線やその他の医療画像を処理します。             製品やサービスの使用について顧客にアドバイスします。
#
#                                   task98                         task99
# 0                            規則や規制を施行する。            運用上の問題や障害の原因を特定します。
# 1               活動を実行するための書面による許可を取得します。  技術的または手続き上の問題について顧客にアドバイスします。
# 2                           顧客に投資を推奨します。        販売やその他のビジネス取引の記録を保持します。
# 3                 法的問題を調査するための公聴会を開催します。            ライセンスまたは許可申請を確認します。
# 4            緊急事態、問題、または危険について他の人に通知します。             状況の詳細を適切な担当者に伝えます。
# ...                                  ...                            ...
# 2963  コンピュータまたは情報セキュリティのポリシーまたは手順を開発します。                   健康や衛生習慣を教える。
# 2964               建設、設置、修理のレイアウトを計画します。             アートやデザインの素材を確認します。
# 2965                 代替医療手法を用いて患者を治療します。         患者の身体的または生理学的特性を測定します。
# 2966                  価格やその他の販売条件を交渉します。                 コストや販売条件を見積もる。
# 2967                       実験室での作業を監督する。           医療活動に関する数値データを計算します。
#
# [2968 rows x 103 columns]
