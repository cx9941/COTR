# %%
import pandas as pd
import os

dataset_name = 'en'
df = pd.read_excel(f'../step3-bert_recall/CuBERT/results/2e-05_32_0.8/{dataset_name}.xlsx')
for seed in range(5):
    if not os.path.exists(f'data/{dataset_name}/seed{seed}/input0'):
        os.makedirs(f'data/{dataset_name}/seed{seed}/input0')
    df.to_csv(f'data/{dataset_name}/seed{seed}/input0/task_candidate.csv', index=None, sep='\t')
df
# Out:
#                                               job_title  \
# 0                               Senior Podcast Producer
# 1                            QC Biochemistry Supervisor
# 2                                    Trailer Technician
# 3             NDT Assistant - Entry Level, Rapid Growth
# 4                        Field Construction Coordinator
# ...                                                 ...
# 7776                           Administrative Assistant
# 7777     Senior Piping Engineer (Remote Eligible, U.S.)
# 7778              Transportation Design Project Manager
# 7779  Casual Patient Care Technician Opportunities! ...
# 7780             Director of Marketing & Communications
#
#                                         job_description  \
# 0     Lead production on assigned series, directing ...
# 1     hiring, performance management and supporting ...
# 2     Demonstrate proficient knowledge of preventati...
# 3     Set up and utilize Nondestructive Test equipme...
# 4     Assisting Construction and Engineering teams w...
# ...                                                 ...
# 7776  - May conduct data analyses and presents findi...
# 7777  The Senior Piping Engineer is required to unde...
# 7778  house Engineers and sub-consultants on City, C...
# 7779  Must routinely perform the UPMC nursing core n...
# 7780  Propose and implement communication and market...
#
#                                                    text  \
# 0     Senior Podcast Producer-Lead production on ass...
# 1     QC Biochemistry Supervisor-hiring, performance...
# 2     Trailer Technician-Demonstrate proficient know...
# 3     NDT Assistant - Entry Level, Rapid Growth-Set ...
# 4     Field Construction Coordinator-Assisting Const...
# ...                                                 ...
# 7776  Administrative Assistant-- May conduct data an...
# 7777  Senior Piping Engineer (Remote Eligible, U.S.)...
# 7778  Transportation Design Project Manager-house En...
# 7779  Casual Patient Care Technician Opportunities! ...
# 7780  Director of Marketing & Communications-Propose...
#
#                                                   task0  \
# 0                        Develop promotional materials.
# 1     Distribute promotional literature or samples t...
# 2     Dispose of biomedical waste in accordance with...
# 3     Drive vehicles to transport individuals or equ...
# 4              Identify sustainable business practices.
# ...                                                 ...
# 7776       Recommend products or services to customers.
# 7777  Select medical equipment for addressing patien...
# 7778               Schedule activities or facility use.
# 7779        Organize recreational activities or events.
# 7780                 Collect data about customer needs.
#
#                                                   task1  \
# 0     Advise customers on the use of products or ser...
# 1         Develop guidelines for system implementation.
# 2            Test facilities for environmental hazards.
# 3                        Harvest agricultural products.
# 4     Advise others on green energy or related techn...
# ...                                                 ...
# 7776      Prepare informational or reference materials.
# 7777  Coordinate construction or installation activi...
# 7778                              Administer first aid.
# 7779             Assist patients with daily activities.
# 7780  Assist clients in handling details of daily life.
#
#                                                   task2  \
# 0                 Present work to clients for approval.
# 1           Determine protocols for medical procedures.
# 2     Inspect cargo to ensure it is properly loaded ...
# 3     Measure stock or liquid levels in sustainable ...
# 4     Maintain current knowledge related to work act...
# ...                                                 ...
# 7776          Perform administrative or clerical tasks.
# 7777  Perform manual agricultural, aquacultural, or ...
# 7778                        Manage outreach activities.
# 7779             Assist individuals with special needs.
# 7780  Explain technical medical information to patie...
#
#                                                   task3  \
# 0     Answer telephones to direct calls or provide i...
# 1     Prepare operational budgets for green energy o...
# 2     Inspect areas for compliance with sanitation s...
# 3     Design energy-efficient vehicles or vehicle co...
# 4     Provide recommendations to others about comput...
# ...                                                 ...
# 7776  Schedule appointments with prospective customers.
# 7777                    Direct installation activities.
# 7778      Assist disabled or incapacitated individuals.
# 7779             Coordinate special events or programs.
# 7780     Help clients get needed services or resources.
#
#                                                   task4  \
# 0     Discuss goods or services information with cus...
# 1                            Research new technologies.
# 2     Design electronic or computer equipment or ins...
# 3                       Test air quality at work sites.
# 4     Search files, databases or reference materials...
# ...                                                 ...
# 7776  Confer with managers to make operational decis...
# 7777  Direct maintenance and repair activities in gr...
# 7778  Confer with clients to discuss treatment plans...
# 7779  Provide health and wellness advice to patients...
# 7780                  Conduct surveys in organizations.
#
#                                                   task5  \
# 0                                Schedule appointments.
# 1     Evaluate green operations or programs for comp...
# 2     Calculate requirements for equipment installat...
# 3               Transport animals, crops, or equipment.
# 4     Develop computer or information security polic...
# ...                                                 ...
# 7776  Evaluate current or prospective maintenance em...
# 7777          Determine forestry techniques or methods.
# 7778  Supervise workers providing client or patient ...
# 7779  Demonstrate activity techniques or equipment use.
# 7780  Update knowledge about emerging industry or te...
#
#                                                   task6  ...  \
# 0        Discuss service options or needs with clients.  ...
# 1     Research engineering applications of emerging ...  ...
# 2                           Maintain computer hardware.  ...
# 3     Inspect facilities, equipment or supplies to e...  ...
# 4                   Develop financial analysis methods.  ...
# ...                                                 ...  ...
# 7776  Observe individuals' activities to gather info...  ...
# 7777           Prepare patient treatment areas for use.  ...
# 7778  Arrange physical or mental health services for...  ...
# 7779   Attend events to develop professional knowledge.  ...
# 7780                 Direct activities of subordinates.  ...
#
#                                                  task90  \
# 0     Provide basic information to guests, visitors,...
# 1     Present food or beverage information or menus ...
# 2                    Design alternative energy systems.
# 3         Maintain recording or broadcasting equipment.
# 4                      Contract real estate to clients.
# ...                                                 ...
# 7776  Appraise environmental impact of regulations o...
# 7777          Analyze chemical compounds or substances.
# 7778  Implement therapeutic programs to improve pati...
# 7779        Engage patients in exercises or activities.
# 7780   Manage financial activities of the organization.
#
#                                                  task91  \
# 0       Record information about suspects or criminals.
# 1     Coordinate shipping activities with external p...
# 2     Read work orders or other instructions to dete...
# 3     Prepare materials or solutions for animal or p...
# 4                          Request emergency personnel.
# ...                                                 ...
# 7776  Advise customers on the use of products or ser...
# 7777             Record operational or production data.
# 7778  Administer basic health care or medical treatm...
# 7779              Research topics in area of expertise.
# 7780                      Write reports or evaluations.
#
#                                                  task92  \
# 0     Direct natural resources management or conserv...
# 1     Record information about environmental conditi...
# 2         Design energy-efficient equipment or systems.
# 3     Inspect condition or functioning of facilities...
# 4     Review documents or materials for compliance w...
# ...                                                 ...
# 7776   Prepare contracts, disclosures, or applications.
# 7777  Evaluate quality of food ingredients or prepar...
# 7778  Train personnel in technical or scientific pro...
# 7779  Confer with family members to discuss client t...
# 7780      Manage clerical or administrative activities.
#
#                                                  task93  \
# 0                   Analyze business or financial data.
# 1               Develop procedures for data management.
# 2     Monitor loading processes to ensure they are p...
# 3     Design tools, fixtures, or other devices for p...
# 4     Resolve issues affecting transportation operat...
# ...                                                 ...
# 7776                       Prepare financial documents.
# 7777  Record information about parts, materials or r...
# 7778    Develop professional relationships or networks.
# 7779                      Evaluate scholarly materials.
# 7780     Analyze impact of legal or regulatory changes.
#
#                                                  task94  \
# 0     Collaborate with others to determine productio...
# 1            Develop technical or scientific databases.
# 2     Measure the level or depth of water or other l...
# 3                                  Measure ingredients.
# 4                    Maintain sterile operative fields.
# ...                                                 ...
# 7776  Provide technical support for computer network...
# 7777              Design environmental control systems.
# 7778  Develop treatment plans that use non-medical t...
# 7779               Treat chronic diseases or disorders.
# 7780  Provide technical information or assistance to...
#
#                                                  task95  \
# 0                              Prepare project budgets.
# 1             Estimate demand for products or services.
# 2                  Arrange artwork, products, or props.
# 3           Test products for functionality or quality.
# 4     Analyze website or related online data to trac...
# ...                                                 ...
# 7776  Disburse funds from clients accounts to credit...
# 7777                     Operate audiovisual equipment.
# 7778                         Treat medical emergencies.
# 7779  Monitor patient progress or responses to treat...
# 7780           Establish nursing policies or standards.
#
#                                                  task96  \
# 0     Observe individuals' activities to gather info...
# 1                 Exchange information with colleagues.
# 2     Operate laboratory equipment to analyze medica...
# 3             Load shipments, belongings, or materials.
# 4       Implement advertising or marketing initiatives.
# ...                                                 ...
# 7776                              Approve expenditures.
# 7777  Monitor building premises to ensure occupant o...
# 7778             Assist individuals with special needs.
# 7779  Train patients, family members, or caregivers ...
# 7780           Inform viewers, listeners, or audiences.
#
#                                                  task97  \
# 0     Test biological specimens to gather informatio...
# 1         Manage environmental sustainability projects.
# 2       Locate animals for fishing or hunting purposes.
# 3     Test communications equipment to ensure proper...
# 4     Search information sources to find specific data.
# ...                                                 ...
# 7776  Plan natural resources conservation or restora...
# 7777              Design medical devices or appliances.
# 7778                       Supervise inmate activities.
# 7779   Develop treatment plans for patients or clients.
# 7780  Provide security escorts for officials, jury m...
#
#                                                  task98  \
# 0       Prepare operational progress or status reports.
# 1                                    Maintain security.
# 2         Signal others to coordinate vehicle movement.
# 3                Test materials, solutions, or samples.
# 4     Advise others on management of emergencies or ...
# ...                                                 ...
# 7776  Discuss goods or services information with cus...
# 7777             Collect environmental data or samples.
# 7778  Demonstrate activity techniques or equipment use.
# 7779                 Direct employee training programs.
# 7780              Prepare medical reports or documents.
#
#                                                  task99
# 0                              Analyze consumer trends.
# 1     Design layout of art or product exhibits, disp...
# 2     Plan layout of construction, installation, or ...
# 3     Prepare hazardous waste for processing or disp...
# 4         Identify opportunities for green initiatives.
# ...                                                 ...
# 7776    Coordinate logistics for productions or events.
# 7777  Monitor surroundings to detect potential hazards.
# 7778  Counsel clients on mental health or personal a...
# 7779   Train caregivers or other non-medical personnel.
# 7780  Answer customer questions about goods or servi...
#
# [7781 rows x 103 columns]
